# %%
import sqlite3
import pandas as pd
from notebook_tools import side_by_side

# import plotly.express as px
# import seaborn as sns

connection = sqlite3.connect("db/vivino.db")
cursor = connection.cursor()

# %%
from notebook_tools import get_sql_table_info

get_sql_table_info(cursor, save_to_file=True, print_out=True)
# Out:
# Table: countries
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	code                    VARCHAR      1       None      1
# 	name                    VARCHAR      0       None      0
# 	regions_count           INTEGER      0       None      0
# 	users_count             INTEGER      0       None      0
# 	wines_count             INTEGER      0       None      0
# 	wineries_count          INTEGER      0       None      0
#
# Table: grapes
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	name                    VARCHAR      0       None      0
#
# Table: wineries
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	name                    VARCHAR      0       None      0
#
# Table: flavor_groups
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	name                    VARCHAR      1       None      1
#
# Table: keywords
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	name                    VARCHAR      0       None      0
#
# Table: regions
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	name                    VARCHAR      0       None      0
# 	country_code            VARCHAR      0       None      0
# Foreign Key Constraints:
# 	COLUMN                  REFERENCES
# 	country_code            countries.code
#
# Table: most_used_grapes_per_country
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	country_code            VARCHAR      0       None      0
# 	grape_id                INTEGER      0       None      0
# 	wines_count             INTEGER      0       None      0
# Foreign Key Constraints:
# 	COLUMN                  REFERENCES
# 	grape_id                grapes.id
# 	country_code            countries.code
#
# Table: toplists
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	name                    VARCHAR(255) 1       None      0
# 	country_code            VARCHAR      0       None      0
# Foreign Key Constraints:
# 	COLUMN                  REFERENCES
# 	country_code            countries.code
#
# Table: wines
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	name                    VARCHAR      0       None      0
# 	is_natural              BOOLEAN      0       None      0
# 	region_id               INTEGER      0       None      0
# 	winery_id               INTEGER      0       None      0
# 	ratings_average         FLOAT        0       None      0
# 	ratings_count           INTEGER      0       None      0
# 	url                     VARCHAR      0       None      0
# 	acidity                 FLOAT        0       None      0
# 	fizziness               FLOAT        0       None      0
# 	intensity               FLOAT        0       None      0
# 	sweetness               FLOAT        0       None      0
# 	tannin                  FLOAT        0       None      0
# 	user_structure_count    INTEGER      0       None      0
# Foreign Key Constraints:
# 	COLUMN                  REFERENCES
# 	winery_id               wineries.id
# 	region_id               regions.id
#
# Table: vintages
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	name                    VARCHAR      0       None      0
# 	wine_id                 INTEGER      0       None      0
# 	ratings_average         FLOAT        0       None      0
# 	ratings_count           INTEGER      0       None      0
# 	year                    INTEGER      0       None      0
# 	price_euros             FLOAT        0       None      0
# 	price_discounted_from   FLOAT        0       None      0
# 	price_discount_percentageFLOAT        0       None      0
# 	bottle_volume_ml        INTEGER      0       None      0
# Foreign Key Constraints:
# 	COLUMN                  REFERENCES
# 	wine_id                 wines.id
#
# Table: keywords_wine
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	keyword_id              INTEGER      1       None      1
# 	wine_id                 INTEGER      1       None      2
# 	group_name              VARCHAR      1       None      3
# 	keyword_type            VARCHAR      0       None      0
# 	count                   INTEGER      0       None      0
# Foreign Key Constraints:
# 	COLUMN                  REFERENCES
# 	wine_id                 wines.id
# 	keyword_id              keywords.id
#
# Table: vintage_toplists_rankings
# Columns:
# 	NAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY
# 	id                      INTEGER      1       None      1
# 	top_list_id             INTEGER      0       None      0
# 	vintage_id              INTEGER      0       None      0
# 	rank                    INTEGER      0       None      0
# 	previous_rank           INTEGER      0       None      0
# Foreign Key Constraints:
# 	COLUMN                  REFERENCES
# 	vintage_id              vintages.id
# 	top_list_id             toplists.id
# '\n\nTable: countries\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tcode                    VARCHAR      1       None      1    \n\tname                    VARCHAR      0       None      0    \n\tregions_count           INTEGER      0       None      0    \n\tusers_count             INTEGER      0       None      0    \n\twines_count             INTEGER      0       None      0    \n\twineries_count          INTEGER      0       None      0    \n\nTable: grapes\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tname                    VARCHAR      0       None      0    \n\nTable: wineries\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tname                    VARCHAR      0       None      0    \n\nTable: flavor_groups\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tname                    VARCHAR      1       None      1    \n\nTable: keywords\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tname                    VARCHAR      0       None      0    \n\nTable: regions\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tname                    VARCHAR      0       None      0    \n\tcountry_code            VARCHAR      0       None      0    \nForeign Key Constraints:\n\tCOLUMN                  REFERENCES\n\tcountry_code            countries.code\n\nTable: most_used_grapes_per_country\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tcountry_code            VARCHAR      0       None      0    \n\tgrape_id                INTEGER      0       None      0    \n\twines_count             INTEGER      0       None      0    \nForeign Key Constraints:\n\tCOLUMN                  REFERENCES\n\tgrape_id                grapes.id\n\tcountry_code            countries.code\n\nTable: toplists\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tname                    VARCHAR(255) 1       None      0    \n\tcountry_code            VARCHAR      0       None      0    \nForeign Key Constraints:\n\tCOLUMN                  REFERENCES\n\tcountry_code            countries.code\n\nTable: wines\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tname                    VARCHAR      0       None      0    \n\tis_natural              BOOLEAN      0       None      0    \n\tregion_id               INTEGER      0       None      0    \n\twinery_id               INTEGER      0       None      0    \n\tratings_average         FLOAT        0       None      0    \n\tratings_count           INTEGER      0       None      0    \n\turl                     VARCHAR      0       None      0    \n\tacidity                 FLOAT        0       None      0    \n\tfizziness               FLOAT        0       None      0    \n\tintensity               FLOAT        0       None      0    \n\tsweetness               FLOAT        0       None      0    \n\ttannin                  FLOAT        0       None      0    \n\tuser_structure_count    INTEGER      0       None      0    \nForeign Key Constraints:\n\tCOLUMN                  REFERENCES\n\twinery_id               wineries.id\n\tregion_id               regions.id\n\nTable: vintages\nColumns:\n\tNAME                    TYPE         NOTNULL DEFAULT   PRIMARY KEY\n\tid                      INTEGER      1       None      1    \n\tname                    VARCHAR      0       None      0  ...

# %%
pd.read_sql_query(
"""
SELECT
    wines.name,
    acidity,
    fizziness,
    intensity,
    sweetness,
    tannin,
    regions.name,
    url
FROM
    wines
    JOIN regions ON regions.id = wines.region_id
WHERE
    wines.name = 'Cabernet Sauvignon'
""", connection)
# Out:
#                  name   acidity fizziness  intensity  sweetness    tannin  \
# 0  Cabernet Sauvignon  3.334017      None   4.709039   1.690490  3.371491
# 1  Cabernet Sauvignon  2.329016      None   3.928453   2.311101  2.895819
# 2  Cabernet Sauvignon  3.284369      None   4.748084   1.936713  3.146816
# 3  Cabernet Sauvignon  3.869297      None   3.964489   1.540390  3.795511
# 4  Cabernet Sauvignon  3.387184      None   4.585916   1.659149  3.429642
# 5  Cabernet Sauvignon  3.884835      None   3.994474   1.644870  3.914068
# 6  Cabernet Sauvignon  3.304091      None   4.700800   1.758352  3.393993
# 7  Cabernet Sauvignon  3.096885      None   4.536795   1.445688  3.653364
#
#                  name                                                url
# 0         Napa Valley  https://www.grandcruwijnen.nl/2018-joseph-phel...
# 1              Veneto  https://www.seulementproduitsitaliens.be/vino/...
# 2         Napa Valley  https://www.wereldwijnonline.be/caymus-caberne...
# 3  Walla Walla Valley  https://www.seulementproduitsitaliens.be/spec_...
# 4         Napa Valley  https://www.grandcruwijnen.nl/2019-forman-napa...
# 5     Columbia Valley  https://www.grandcruwijnen.nl/2018-quilceda-cr...
# 6          Rutherford  https://www.seulementproduitsitaliens.be/spec_...
# 7          California  https://hermanwines.com/products/cabernet-sauv...

# %% [markdown]
# ### Ratings overview: 10 most profitable wines?

# %%
q = """
SELECT
    wines.ratings_average AS 'avg rating',
    wines.ratings_count AS 'rating count'
FROM
    wines
"""

wine_df = pd.read_sql_query(q, connection)

q = """
SELECT
    vintages.ratings_average AS 'avg rating',
    vintages.ratings_count AS 'rating count'
FROM
    vintages
WHERE
    ratings_count AND ratings_average > 0
"""

vintages_df = pd.read_sql_query(q, connection)

side_by_side({
    "WINES Ratings": wine_df.describe(),
    # "WINES Correlation": wine_df.corr(),
    "VINTAGES Ratings": vintages_df.describe(),
    # "VINTAGES Correlation": vintages_df.corr(),
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_88325" style='display:inline; vertical-align:top;'>
#   <caption>WINES Ratings</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88325_level0_col0" class="col_heading level0 col0" >avg rating</th>
#       <th id="T_88325_level0_col1" class="col_heading level0 col1" >rating count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88325_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_88325_row0_col0" class="data row0 col0" >1020.000000</td>
#       <td id="T_88325_row0_col1" class="data row0 col1" >1020.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88325_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_88325_row1_col0" class="data row1 col0" >4.443431</td>
#       <td id="T_88325_row1_col1" class="data row1 col1" >6387.334314</td>
#     </tr>
#     <tr>
#       <th id="T_88325_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_88325_row2_col0" class="data row2 col0" >0.118239</td>
#       <td id="T_88325_row2_col1" class="data row2 col1" >14022.610539</td>
#     </tr>
#     <tr>
#       <th id="T_88325_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_88325_row3_col0" class="data row3 col0" >4.100000</td>
#       <td id="T_88325_row3_col1" class="data row3 col1" >27.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88325_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_88325_row4_col0" class="data row4 col0" >4.400000</td>
#       <td id="T_88325_row4_col1" class="data row4 col1" >474.000000</td>
#     </tr>
#     <tr>
#       <th id="T_88325_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_88325_row5_col0" class="data row5 col0" >4.400000</td>
#       <td id="T_88325_row5_col1" class="data row5 col1" >1697.500000</td>
#     </tr>
#     <tr>
#       <th id="T_88325_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_88325_row6_col0" class="data row6 col0" >4.500000</td>
#       <td id="T_88325_row6_col1" class="data row6 col1" >5644.750000</td>
#     </tr>
#     <tr>
#       <th id="T_88325_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_88325_row7_col0" class="data row7 col0" >4.800000</td>
#       <td id="T_88325_row7_col1" class="data row7 col1" >157944.000000</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_22f21" style='display:inline; vertical-align:top;'>
#   <caption>VINTAGES Ratings</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22f21_level0_col0" class="col_heading level0 col0" >avg rating</th>
#       <th id="T_22f21_level0_col1" class="col_heading level0 col1" >rating count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22f21_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_22f21_row0_col0" class="data row0 col0" >1540.000000</td>
#       <td id="T_22f21_row0_col1" class="data row0 col1" >1540.000000</td>
#     </tr>
#     <tr>
#       <th id="T_22f21_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_22f21_row1_col0" class="data row1 col0" >4.532338</td>
#       <td id="T_22f21_row1_col1" class="data row1 col1" >697.123377</td>
#     </tr>
#     <tr>
#       <th id="T_22f21_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_22f21_row2_col0" class="data row2 col0" >0.107695</td>
#       <td id="T_22f21_row2_col1" class="data row2 col1" >2050.359023</td>
#     </tr>
#     <tr>
#       <th id="T_22f21_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_22f21_row3_col0" class="data row3 col0" >4.400000</td>
#       <td id="T_22f21_row3_col1" class="data row3 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_22f21_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_22f21_row4_col0" class="data row4 col0" >4.400000</td>
#       <td id="T_22f21_row4_col1" class="data row4 col1" >100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_22f21_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_22f21_row5_col0" class="data row5 col0" >4.500000</td>
#       <td id="T_22f21_row5_col1" class="data row5 col1" >230.000000</td>
#     </tr>
#     <tr>
#       <th id="T_22f21_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_22f21_row6_col0" class="data row6 col0" >4.600000</td>
#       <td id="T_22f21_row6_col1" class="data row6 col1" >559.000000</td>
#     </tr>
#     <tr>
#       <th id="T_22f21_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_22f21_row7_col0" class="data row7 col0" >4.900000</td>
#       <td id="T_22f21_row7_col1" class="data row7 col1" >36681.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
q = """
SELECT
    wines.name AS Wine,
    --wines.id AS ID,
    vintages.name AS Vintage,
    CAST(AVG(vintages.price_euros) AS INT) AS 'Price €',
    wines.ratings_average AS Rating,
    SUM(wines.ratings_count) AS Count,
    CAST(wines.ratings_average * LOG(wines.ratings_count * 0.0001) * vintages.price_euros / 10 AS INT) AS Score,
    regions.name AS Region,
    countries.name AS Country,
    vtr.rank
FROM
    wines
    JOIN vintages ON vintages.wine_id = wines.id
    JOIN regions ON regions.id = wines.region_id
    JOIN countries ON countries.code = regions.country_code
    JOIN vintage_toplists_rankings vtr ON vtr.vintage_id = vintages.id
GROUP BY
    wines.id
ORDER BY
    Score DESC
LIMIT 10
"""

pd.read_sql_query(q, connection).head(60)
# Out:
#                                             Wine  \
# 0                                      Sassicaia
# 1             Cristal Brut Champagne (Millésimé)
# 2            Pauillac (Premier Grand Cru Classé)
# 3                                        Toscana
# 4  Grand Vin Pauillac (Premier Grand Cru Classé)
# 5            Pauillac (Premier Grand Cru Classé)
# 6     Château Margaux (Premier Grand Cru Classé)
# 7                                     Tignanello
# 8                                        Vintage
# 9                    Pauillac (Grand Cru Classé)
#
#                                              Vintage  Price €  Rating   Count  \
# 0                    Tenuta San Guido Sassicaia 1988     2668     4.6  107646
# 1  Louis Roederer Cristal Brut Champagne (Millési...     1900     4.6   84912
# 2  Château Lafite Rothschild Pauillac (Premier Gr...     1900     4.6   78566
# 3                               Masseto Toscana 2006     4633     4.7   81420
# 4  Château Latour Grand Vin Pauillac (Premier Gra...     1505     4.6   77042
# 5  Château Mouton Rothschild Pauillac (Premier Gr...     1038     4.6   73615
# 6  Château Margaux Château Margaux (Premier Grand...     1077     4.6   45350
# 7                           Antinori Tignanello 2016      620     4.5  285026
# 8                                  Krug Vintage 2002     1691     4.6   50754
# 9  Château Pontet-Canet Pauillac (Grand Cru Class...      438     4.4  141702
#
#    Score              Region Country  rank
# 0   1266  Bolgheri Sassicaia  Italie     2
# 1    548           Champagne  France     5
# 2    519            Pauillac  France     2
# 3    488             Toscana  Italie     1
# 4    454            Pauillac  France     2
# 5    414            Pauillac  France     3
# 6    325             Margaux  France     1
# 7    218             Toscana  Italie    10
# 8    189           Champagne  France     7
# 9    177            Pauillac  France     5

# %% [markdown]
# ### Marketing budget: which country?

# %%
q = """
SELECT
    countries.name,
    countries.users_count,
    countries.users_count / wineries_count AS users_per_winery
FROM
    countries
ORDER BY countries.users_count DESC
LIMIT 10
"""

df = pd.read_sql_query(q, connection)
df

q = """
SELECT
    countries.name,
    countries.users_count,
    countries.users_count / wineries_count AS users_per_winery
FROM
    countries
ORDER BY users_per_winery DESC
LIMIT 10
"""

df2 = pd.read_sql_query(q, connection)
df2

side_by_side({
    "Ordered by user count": df,
    "Ordered by users/winery": df2
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_7638a" style='display:inline; vertical-align:top;'>
#   <caption>Ordered by user count</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7638a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7638a_level0_col1" class="col_heading level0 col1" >users_count</th>
#       <th id="T_7638a_level0_col2" class="col_heading level0 col2" >users_per_winery</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7638a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7638a_row0_col0" class="data row0 col0" >États-Unis</td>
#       <td id="T_7638a_row0_col1" class="data row0 col1" >12273684</td>
#       <td id="T_7638a_row0_col2" class="data row0 col2" >436</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7638a_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_7638a_row1_col1" class="data row1 col1" >5973301</td>
#       <td id="T_7638a_row1_col2" class="data row1 col2" >88</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7638a_row2_col0" class="data row2 col0" >Italie</td>
#       <td id="T_7638a_row2_col1" class="data row2 col1" >4270717</td>
#       <td id="T_7638a_row2_col2" class="data row2 col2" >100</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7638a_row3_col0" class="data row3 col0" >Allemagne</td>
#       <td id="T_7638a_row3_col1" class="data row3 col1" >2549989</td>
#       <td id="T_7638a_row3_col2" class="data row3 col2" >186</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7638a_row4_col0" class="data row4 col0" >Espagne</td>
#       <td id="T_7638a_row4_col1" class="data row4 col1" >2264396</td>
#       <td id="T_7638a_row4_col2" class="data row4 col2" >125</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7638a_row5_col0" class="data row5 col0" >Suisse</td>
#       <td id="T_7638a_row5_col1" class="data row5 col1" >1601799</td>
#       <td id="T_7638a_row5_col2" class="data row5 col2" >416</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7638a_row6_col0" class="data row6 col0" >Portugal</td>
#       <td id="T_7638a_row6_col1" class="data row6 col1" >1123535</td>
#       <td id="T_7638a_row6_col2" class="data row6 col2" >192</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7638a_row7_col0" class="data row7 col0" >Australie</td>
#       <td id="T_7638a_row7_col1" class="data row7 col1" >1022965</td>
#       <td id="T_7638a_row7_col2" class="data row7 col2" >73</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7638a_row8_col0" class="data row8 col0" >Argentine</td>
#       <td id="T_7638a_row8_col1" class="data row8 col1" >629532</td>
#       <td id="T_7638a_row8_col2" class="data row8 col2" >117</td>
#     </tr>
#     <tr>
#       <th id="T_7638a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7638a_row9_col0" class="data row9 col0" >Chili</td>
#       <td id="T_7638a_row9_col1" class="data row9 col1" >326757</td>
#       <td id="T_7638a_row9_col2" class="data row9 col2" >56</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b4a56" style='display:inline; vertical-align:top;'>
#   <caption>Ordered by users/winery</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4a56_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_b4a56_level0_col1" class="col_heading level0 col1" >users_count</th>
#       <th id="T_b4a56_level0_col2" class="col_heading level0 col2" >users_per_winery</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4a56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b4a56_row0_col0" class="data row0 col0" >États-Unis</td>
#       <td id="T_b4a56_row0_col1" class="data row0 col1" >12273684</td>
#       <td id="T_b4a56_row0_col2" class="data row0 col2" >436</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b4a56_row1_col0" class="data row1 col0" >Suisse</td>
#       <td id="T_b4a56_row1_col1" class="data row1 col1" >1601799</td>
#       <td id="T_b4a56_row1_col2" class="data row1 col2" >416</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b4a56_row2_col0" class="data row2 col0" >Roumanie</td>
#       <td id="T_b4a56_row2_col1" class="data row2 col1" >228185</td>
#       <td id="T_b4a56_row2_col2" class="data row2 col2" >332</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b4a56_row3_col0" class="data row3 col0" >Israël</td>
#       <td id="T_b4a56_row3_col1" class="data row3 col1" >150549</td>
#       <td id="T_b4a56_row3_col2" class="data row3 col2" >284</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b4a56_row4_col0" class="data row4 col0" >Portugal</td>
#       <td id="T_b4a56_row4_col1" class="data row4 col1" >1123535</td>
#       <td id="T_b4a56_row4_col2" class="data row4 col2" >192</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b4a56_row5_col0" class="data row5 col0" >Allemagne</td>
#       <td id="T_b4a56_row5_col1" class="data row5 col1" >2549989</td>
#       <td id="T_b4a56_row5_col2" class="data row5 col2" >186</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b4a56_row6_col0" class="data row6 col0" >Espagne</td>
#       <td id="T_b4a56_row6_col1" class="data row6 col1" >2264396</td>
#       <td id="T_b4a56_row6_col2" class="data row6 col2" >125</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b4a56_row7_col0" class="data row7 col0" >Argentine</td>
#       <td id="T_b4a56_row7_col1" class="data row7 col1" >629532</td>
#       <td id="T_b4a56_row7_col2" class="data row7 col2" >117</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b4a56_row8_col0" class="data row8 col0" >Italie</td>
#       <td id="T_b4a56_row8_col1" class="data row8 col1" >4270717</td>
#       <td id="T_b4a56_row8_col2" class="data row8 col2" >100</td>
#     </tr>
#     <tr>
#       <th id="T_b4a56_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b4a56_row9_col0" class="data row9 col0" >France</td>
#       <td id="T_b4a56_row9_col1" class="data row9 col1" >5973301</td>
#       <td id="T_b4a56_row9_col2" class="data row9 col2" >88</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3 Relevant Wineries

# %%
q = """
WITH temp2 AS (
    WITH temp AS (
        SELECT
            vintages.name AS Vintage,
            wines.name AS Wine,
            vtr.rank AS Rank,
            vintages.ratings_average AS Ratings,
            vintages.ratings_count AS Count,
            vintages.year as Year
        FROM
            vintages
            JOIN wines ON vintages.wine_id = wines.id
            LEFT JOIN vintage_toplists_rankings AS vtr ON vtr.vintage_id = vintages.id
        WHERE
            vintages.year != 'N.V.'
            AND vintages.year > 2010
            AND Ratings != 0
            --AND Rank != 'None'
    )
    SELECT
        SUBSTR(Vintage, 1, LENGTH(Vintage) - LENGTH(Wine) - 6) AS Winery,
        MAX(Year) AS LatestYear,
        --Wine,
        --Vintage,
        --MIN(Rank) AS 'Best Rank',
        MAX(Ratings) AS Ratings,
        SUM(Count) AS Count
    FROM temp
    GROUP BY
        Winery
    ORDER BY
        Count DESC
)
SELECT
    Winery,
    LatestYear AS 'Latest Year',
    Ratings AS 'Best Rating',
    Count AS Popularity,
    Ratings * LOG(Count * 0.000001 + 1.5) AS Score
FROM
    temp2
ORDER BY
    Score DESC
LIMIT 3
"""

df = pd.read_sql_query(q, connection)
side_by_side({
    "": df
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_6a0ba" style='display:inline; vertical-align:top;'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a0ba_level0_col0" class="col_heading level0 col0" >Winery</th>
#       <th id="T_6a0ba_level0_col1" class="col_heading level0 col1" >Latest Year</th>
#       <th id="T_6a0ba_level0_col2" class="col_heading level0 col2" >Best Rating</th>
#       <th id="T_6a0ba_level0_col3" class="col_heading level0 col3" >Popularity</th>
#       <th id="T_6a0ba_level0_col4" class="col_heading level0 col4" >Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a0ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a0ba_row0_col0" class="data row0 col0" >Antinori</td>
#       <td id="T_6a0ba_row0_col1" class="data row0 col1" >2021</td>
#       <td id="T_6a0ba_row0_col2" class="data row0 col2" >4.700000</td>
#       <td id="T_6a0ba_row0_col3" class="data row0 col3" >75989</td>
#       <td id="T_6a0ba_row0_col4" class="data row0 col4" >0.928500</td>
#     </tr>
#     <tr>
#       <th id="T_6a0ba_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6a0ba_row1_col0" class="data row1 col0" >Tenuta San Guido</td>
#       <td id="T_6a0ba_row1_col1" class="data row1 col1" >2020</td>
#       <td id="T_6a0ba_row1_col2" class="data row1 col2" >4.700000</td>
#       <td id="T_6a0ba_row1_col3" class="data row1 col3" >48554</td>
#       <td id="T_6a0ba_row1_col4" class="data row1 col4" >0.892654</td>
#     </tr>
#     <tr>
#       <th id="T_6a0ba_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6a0ba_row2_col0" class="data row2 col0" >Casanova di Neri</td>
#       <td id="T_6a0ba_row2_col1" class="data row2 col1" >2018</td>
#       <td id="T_6a0ba_row2_col2" class="data row2 col2" >4.800000</td>
#       <td id="T_6a0ba_row2_col3" class="data row2 col3" >17436</td>
#       <td id="T_6a0ba_row2_col4" class="data row2 col4" >0.869330</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Coffee, Toast, Cream, Green Apple and Citrus

# %%
q = """
WITH concat_keywords AS (
    SELECT
        wines.name AS Wine,
        wines.ratings_average AS Rating,
        keywords_wine.count AS count,
        keywords.name AS keyword,
        GROUP_CONCAT(keywords.name) AS AllKeywords
    FROM
        keywords_wine
        JOIN wines ON keywords_wine.wine_id = wines.id
        JOIN keywords ON keywords_wine.keyword_id = keywords.id
    WHERE
        keyword IN ("coffee", "toast", "green apple", "cream", "citrus")
        AND count > 9
    GROUP BY
        wines.id
)
SELECT
    Wine,
    AllKeywords,
    Rating
FROM
    concat_keywords
WHERE
    AllKeywords LIKE '%coffee%'
    AND AllKeywords LIKE '%toast%'
    AND AllKeywords LIKE '%green apple%'
    AND AllKeywords LIKE '%cream%'
    AND AllKeywords LIKE '%citrus%'
ORDER BY
    Rating DESC
"""

df = pd.read_sql_query(q, connection)
df.head(60)
# Out:
#                                                  Wine  \
# 0   Le Mesnil Blanc de Blancs (Cuvée S) Brut Champ...
# 1                                           Sauternes
# 2                         P2 Plénitude Brut Champagne
# 3                  Cristal Brut Champagne (Millésimé)
# 4                                             Vintage
# 5                                      Brut Champagne
# 6        R.D Extra Brut Champagne (Récemment Dégorgé)
# 7                               Blanc des Millénaires
# 8                Sir Winston Churchill Brut Champagne
# 9                                        Grande Cuvée
# 10                     La Grande Année Brut Champagne
# 11                        Belle Epoque Brut Champagne
# 12                      La Grande Dame Brut Champagne
# 13                Comtes de Champagne Blanc de Blancs
# 14                                                 MV
# 15         Dom Ruinart Blanc de Blancs Brut Champagne
# 16             Cuvée des Enchanteleurs Brut Champagne
# 17                                Trebbiano d'Abruzzo
# 18               Sauternes (Premier Grand Cru Classé)
#
#                                           AllKeywords  Rating
# 0   citrus,toast,coffee,coffee,cream,toast,green a...     4.7
# 1   green apple,coffee,toast,coffee,citrus,cream,t...     4.7
# 2   toast,coffee,coffee,cream,toast,green apple,ci...     4.7
# 3   toast,coffee,green apple,citrus,coffee,cream,t...     4.6
# 4   toast,coffee,coffee,cream,toast,green apple,ci...     4.6
# 5   toast,coffee,cream,toast,coffee,green apple,ci...     4.6
# 6   toast,coffee,coffee,cream,toast,green apple,ci...     4.6
# 7   toast,coffee,coffee,cream,toast,citrus,green a...     4.6
# 8   toast,coffee,coffee,cream,toast,green apple,ci...     4.6
# 9   toast,coffee,coffee,cream,toast,citrus,green a...     4.6
# 10  toast,coffee,coffee,cream,toast,green apple,ci...     4.5
# 11  green apple,toast,coffee,citrus,cream,toast,co...     4.5
# 12  toast,coffee,coffee,green apple,cream,toast,ci...     4.5
# 13  toast,coffee,cream,toast,coffee,citrus,green a...     4.5
# 14  coffee,toast,coffee,green apple,cream,toast,ci...     4.5
# 15  toast,coffee,cream,toast,coffee,green apple,ci...     4.5
# 16  toast,coffee,coffee,cream,toast,green apple,ci...     4.5
# 17  coffee,green apple,citrus,toast,coffee,cream,t...     4.4
# 18  green apple,coffee,toast,coffee,citrus,cream,t...     4.4

# %% [markdown]
# ### TOP 5 Wines for the TOP 3 Grapes

# %%
q = """
WITH ranked_wines AS (
    SELECT
        wines.name AS Wine,
        grapes.name AS Grape,
        wines.ratings_average AS 'Rating',
        countries.name AS Country,
        ROW_NUMBER() OVER(PARTITION BY grapes.name ORDER BY wines.ratings_average DESC) AS wine_rank
    FROM
        wines
        JOIN regions ON wines.region_id = regions.id
        JOIN countries ON regions.country_code = countries.code
        JOIN most_used_grapes_per_country AS mugpc ON countries.code = mugpc.country_code
        JOIN grapes ON grapes.id = mugpc.grape_id
    WHERE
        grapes.name IN (
            SELECT
                distinct(name)
            FROM
                most_used_grapes_per_country AS mugpc
                JOIN grapes ON grapes.id = mugpc.grape_id
            ORDER BY
                wines_count DESC
            LIMIT 3
        )
    ORDER BY
        wines.ratings_average DESC
)
SELECT
    Wine,
    Grape,
    Country,
    Rating
FROM
    ranked_wines
WHERE
    wine_rank <= 5
ORDER BY
    Grape, Rating DESC;
"""

wines_df = pd.read_sql_query(q, connection)
wines_df.head(50)
# Out:
#                                            Wine               Grape  \
# 0                            Cabernet Sauvignon  Cabernet Sauvignon
# 1                                        Mágico  Cabernet Sauvignon
# 2                                 IX Estate Red  Cabernet Sauvignon
# 3          Special Selection Cabernet Sauvignon  Cabernet Sauvignon
# 4                Unico Reserva Especial Edición  Cabernet Sauvignon
# 5   Amarone della Valpolicella Classico Riserva          Chardonnay
# 6                            Cabernet Sauvignon          Chardonnay
# 7                    Fratini Bolgheri Superiore          Chardonnay
# 8                       Cristal Rosé Vinothèque          Chardonnay
# 9                   Batard-Montrachet Grand Cru          Chardonnay
# 10                           Cabernet Sauvignon          Pinot Noir
# 11                      Cristal Rosé Vinothèque          Pinot Noir
# 12                  Batard-Montrachet Grand Cru          Pinot Noir
# 13                                IX Estate Red          Pinot Noir
# 14         Special Selection Cabernet Sauvignon          Pinot Noir
#
#        Country  Rating
# 0   États-Unis     4.8
# 1      Espagne     4.8
# 2   États-Unis     4.7
# 3   États-Unis     4.7
# 4      Espagne     4.7
# 5       Italie     4.8
# 6   États-Unis     4.8
# 7       Italie     4.8
# 8       France     4.8
# 9       France     4.8
# 10  États-Unis     4.8
# 11      France     4.8
# 12      France     4.8
# 13  États-Unis     4.7
# 14  États-Unis     4.7

# %% [markdown]
# ### AVG Wine rating for each country and each vintage

# %%
q = """
SELECT
    avg(wines.ratings_average) AS AverageRating,
    sum(wines.ratings_count) AS RatingCount,
    countries.name AS Country
FROM
    wines
    JOIN regions ON regions.id = wines.region_id
    JOIN countries ON countries.code = regions.country_code
WHERE
    wines.ratings_average AND wines.ratings_count > 0
GROUP BY
    Country
ORDER BY
    AverageRating DESC
"""

wine_df = pd.read_sql_query(q, connection)

q = """
SELECT
    avg(vintages.ratings_average) AS AverageRating,
    sum(vintages.ratings_count) AS RatingCount,
    countries.name AS Country
FROM
    vintages
    JOIN wines ON wines.id = vintages.wine_id
    JOIN regions ON regions.id = wines.region_id
    JOIN countries ON countries.code = regions.country_code
WHERE
    vintages.ratings_average AND vintages.ratings_count > 0
GROUP BY
    Country
ORDER BY
    AverageRating DESC
"""

vintages_df = pd.read_sql_query(q, connection)

side_by_side({
    "Wines": wine_df,
    "Vintages": vintages_df
})
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ef35" style='display:inline; vertical-align:top;'>
#   <caption>Wines</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ef35_level0_col0" class="col_heading level0 col0" >AverageRating</th>
#       <th id="T_6ef35_level0_col1" class="col_heading level0 col1" >RatingCount</th>
#       <th id="T_6ef35_level0_col2" class="col_heading level0 col2" >Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6ef35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6ef35_row0_col0" class="data row0 col0" >4.500000</td>
#       <td id="T_6ef35_row0_col1" class="data row0 col1" >894</td>
#       <td id="T_6ef35_row0_col2" class="data row0 col2" >Israël</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6ef35_row1_col0" class="data row1 col0" >4.500000</td>
#       <td id="T_6ef35_row1_col1" class="data row1 col1" >8257</td>
#       <td id="T_6ef35_row1_col2" class="data row1 col2" >Allemagne</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6ef35_row2_col0" class="data row2 col0" >4.490541</td>
#       <td id="T_6ef35_row2_col1" class="data row2 col1" >834263</td>
#       <td id="T_6ef35_row2_col2" class="data row2 col2" >États-Unis</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6ef35_row3_col0" class="data row3 col0" >4.480000</td>
#       <td id="T_6ef35_row3_col1" class="data row3 col1" >14114</td>
#       <td id="T_6ef35_row3_col2" class="data row3 col2" >Moldavie</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6ef35_row4_col0" class="data row4 col0" >4.472727</td>
#       <td id="T_6ef35_row4_col1" class="data row4 col1" >30564</td>
#       <td id="T_6ef35_row4_col2" class="data row4 col2" >Hongrie</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6ef35_row5_col0" class="data row5 col0" >4.459091</td>
#       <td id="T_6ef35_row5_col1" class="data row5 col1" >59995</td>
#       <td id="T_6ef35_row5_col2" class="data row5 col2" >Afrique du Sud</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6ef35_row6_col0" class="data row6 col0" >4.458333</td>
#       <td id="T_6ef35_row6_col1" class="data row6 col1" >52138</td>
#       <td id="T_6ef35_row6_col2" class="data row6 col2" >Australie</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6ef35_row7_col0" class="data row7 col0" >4.447130</td>
#       <td id="T_6ef35_row7_col1" class="data row7 col1" >2124809</td>
#       <td id="T_6ef35_row7_col2" class="data row7 col2" >France</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6ef35_row8_col0" class="data row8 col0" >4.443617</td>
#       <td id="T_6ef35_row8_col1" class="data row8 col1" >746710</td>
#       <td id="T_6ef35_row8_col2" class="data row8 col2" >Espagne</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6ef35_row9_col0" class="data row9 col0" >4.435714</td>
#       <td id="T_6ef35_row9_col1" class="data row9 col1" >62454</td>
#       <td id="T_6ef35_row9_col2" class="data row9 col2" >Portugal</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6ef35_row10_col0" class="data row10 col0" >4.431250</td>
#       <td id="T_6ef35_row10_col1" class="data row10 col1" >159256</td>
#       <td id="T_6ef35_row10_col2" class="data row10 col2" >Chili</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6ef35_row11_col0" class="data row11 col0" >4.430026</td>
#       <td id="T_6ef35_row11_col1" class="data row11 col1" >2135839</td>
#       <td id="T_6ef35_row11_col2" class="data row11 col2" >Italie</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6ef35_row12_col0" class="data row12 col0" >4.417391</td>
#       <td id="T_6ef35_row12_col1" class="data row12 col1" >283673</td>
#       <td id="T_6ef35_row12_col2" class="data row12 col2" >Argentine</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6ef35_row13_col0" class="data row13 col0" >4.400000</td>
#       <td id="T_6ef35_row13_col1" class="data row13 col1" >166</td>
#       <td id="T_6ef35_row13_col2" class="data row13 col2" >Roumanie</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6ef35_row14_col0" class="data row14 col0" >4.400000</td>
#       <td id="T_6ef35_row14_col1" class="data row14 col1" >610</td>
#       <td id="T_6ef35_row14_col2" class="data row14 col2" >Grèce</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6ef35_row15_col0" class="data row15 col0" >4.350000</td>
#       <td id="T_6ef35_row15_col1" class="data row15 col1" >1047</td>
#       <td id="T_6ef35_row15_col2" class="data row15 col2" >Suisse</td>
#     </tr>
#     <tr>
#       <th id="T_6ef35_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6ef35_row16_col0" class="data row16 col0" >4.300000</td>
#       <td id="T_6ef35_row16_col1" class="data row16 col1" >292</td>
#       <td id="T_6ef35_row16_col2" class="data row16 col2" >Croatie</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_ac322" style='display:inline; vertical-align:top;'>
#   <caption>Vintages</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac322_level0_col0" class="col_heading level0 col0" >AverageRating</th>
#       <th id="T_ac322_level0_col1" class="col_heading level0 col1" >RatingCount</th>
#       <th id="T_ac322_level0_col2" class="col_heading level0 col2" >Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac322_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac322_row0_col0" class="data row0 col0" >4.600000</td>
#       <td id="T_ac322_row0_col1" class="data row0 col1" >62</td>
#       <td id="T_ac322_row0_col2" class="data row0 col2" >Grèce</td>
#     </tr>
#     <tr>
#       <th id="T_ac322_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ac322_row1_col0" class="data row1 col0" >4.556495</td>
#       <td id="T_ac322_row1_col1" class="data row1 col1" >402781</td>
#       <td id="T_ac322_row1_col2" class="data row1 col2" >France</td>
#     </tr>
#     <tr>
#       <th id="T_ac322_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ac322_row2_col0" class="data row2 col0" >4.551648</td>
#       <td id="T_ac322_row2_col1" class="data row2 col1" >102030</td>
#       <td id="T_ac322_row2_col2" class="data row2 col2" >États-Unis</td>
#     </tr>
#     <tr>
#       <th id="T_ac322_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ac322_row3_col0" class="data row3 col0" >4.530000</td>
#       <td id="T_ac322_row3_col1" class="data row3 col1" >3723</td>
#       <td id="T_ac322_row3_col2" class="data row3 col2" >Australie</td>
#     </tr>
#     <tr>
#       <th id="T_ac322_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ac322_row4_col0" class="data row4 col0" >4.522790</td>
#       <td id="T_ac322_row4_col1" class="data row4 col1" >465884</td>
#       <td id="T_ac322_row4_col2" class="data row4 col2" >Italie</td>
#     </tr>
#     <tr>
#       <th id="T_ac322_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ac322_row5_col0" class="data row5 col0" >4.522222</td>
#       <td id="T_ac322_row5_col1" class="data row5 col1" >780</td>
#       <td id="T_ac322_row5_col2" class="data row5 col2" >Allemagne</td>

# %% [markdown]
# ### TOP 5 Cabernet Sauvignon pour Monsieur Vielle-Pie

# %%
q = """
SELECT
    wines.name AS Wine,
    grapes.name AS Grape,
    wines.ratings_average AS Rating,
    wines.ratings_count AS 'Ratings Count',
    wines.ratings_average * LOG(wines.ratings_count * 0.000001 + 2.2) AS Popularity
FROM
    wines
    JOIN regions ON regions.id = wines.region_id
    JOIN countries ON countries.code = regions.country_code
    JOIN most_used_grapes_per_country AS mugpc ON mugpc.country_code = countries.code
    JOIN grapes ON grapes.id = mugpc.grape_id
WHERE Grape = 'Cabernet Sauvignon'
ORDER BY
    Popularity DESC
LIMIT 5
"""

df = pd.read_sql_query(q, connection)
df
# Out:
#                                    Wine               Grape  Rating  \
# 0                    Cabernet Sauvignon  Cabernet Sauvignon     4.6
# 1                                 Unico  Cabernet Sauvignon     4.7
# 2  Special Selection Cabernet Sauvignon  Cabernet Sauvignon     4.7
# 3                    Cabernet Sauvignon  Cabernet Sauvignon     4.8
# 4                              Opus One  Cabernet Sauvignon     4.6
#
#    Ratings Count  Popularity
# 0         157944    1.713654
# 1          45140    1.650844
# 2          41236    1.647292
# 3           2941    1.646414
# 4          77053    1.643916
